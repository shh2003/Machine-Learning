# %%
# Colab 환경일 때만 실행
# from google.colab import drive
# drive.mount('/content/drive')

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
FILE_PATH = "/content/drive/MyDrive/Colab Notebooks/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt"

# %%
df = pd.read_csv(FILE_PATH, header=None, on_bad_lines='skip')

# %%
df
# Out:
#           0        1                2         3          4             5
# 0        33  Jogging   49105962326000 -0.694638  12.680544   0.50395286;
# 1        33  Jogging   49106062271000  5.012288  11.264028   0.95342433;
# 2        33  Jogging   49106112167000  4.903325  10.882658  -0.08172209;
# 3        33  Jogging   49106222305000 -0.612916  18.496431    3.0237172;
# 4        33  Jogging   49106332290000 -1.184970  12.108489     7.205164;
# ...      ..      ...              ...       ...        ...           ...
# 1086461  19  Sitting  131623331483000  9.000000  -1.570000         1.69;
# 1086462  19  Sitting  131623371431000  9.040000  -1.460000         1.73;
# 1086463  19  Sitting  131623411592000  9.080000  -1.380000         1.69;
# 1086464  19  Sitting  131623491487000  9.000000  -1.460000         1.73;
# 1086465  19  Sitting  131623531465000  8.880000  -1.330000         1.61;
#
# [1086466 rows x 6 columns]

# %%
df.columns = ['user', 'activity', 'timestamp', 'x', 'y', 'z']

# %%
# z 끝에 붙는 세미콜론 제거 후 숫자형 변환
df['z'] = df['z'].astype(str).str.replace(';','', regex=False)
df['z'] = pd.to_numeric(df['z'], errors='coerce')  # 숫자 변환

# NaN
print(f"변환 전: {len(df)}")
df = df.dropna()
print(f"NaN 제거 후: {len(df)}")

df = df.drop(columns=["timestamp"])
# Out:
# 변환 전: 1086466
# NaN 제거 후: 1086465

# %%
df
# Out:
#          user activity         x          y         z
# 0          33  Jogging -0.694638  12.680544  0.503953
# 1          33  Jogging  5.012288  11.264028  0.953424
# 2          33  Jogging  4.903325  10.882658 -0.081722
# 3          33  Jogging -0.612916  18.496431  3.023717
# 4          33  Jogging -1.184970  12.108489  7.205164
# ...       ...      ...       ...        ...       ...
# 1086461    19  Sitting  9.000000  -1.570000  1.690000
# 1086462    19  Sitting  9.040000  -1.460000  1.730000
# 1086463    19  Sitting  9.080000  -1.380000  1.690000
# 1086464    19  Sitting  9.000000  -1.460000  1.730000
# 1086465    19  Sitting  8.880000  -1.330000  1.610000
#
# [1086465 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# user        0
# activity    0
# x           0
# y           0
# z           0
# dtype: int64

# %%
df['activity'].value_counts()
# Out:
# activity
# Walking       418393
# Jogging       336445
# Upstairs      122869
# Downstairs    100425
# Sitting        59939
# Standing       48394
# Name: count, dtype: int64

# %%
print(df.shape)
df
# Out:
# (1086465, 5)
#          user activity         x          y         z
# 0          33  Jogging -0.694638  12.680544  0.503953
# 1          33  Jogging  5.012288  11.264028  0.953424
# 2          33  Jogging  4.903325  10.882658 -0.081722
# 3          33  Jogging -0.612916  18.496431  3.023717
# 4          33  Jogging -1.184970  12.108489  7.205164
# ...       ...      ...       ...        ...       ...
# 1086461    19  Sitting  9.000000  -1.570000  1.690000
# 1086462    19  Sitting  9.040000  -1.460000  1.730000
# 1086463    19  Sitting  9.080000  -1.380000  1.690000
# 1086464    19  Sitting  9.000000  -1.460000  1.730000
# 1086465    19  Sitting  8.880000  -1.330000  1.610000
#
# [1086465 rows x 5 columns]

# %%
# 라벨 인코딩
le = LabelEncoder()
df['label_id'] = le.fit_transform(df['activity'])
num_classes = len(le.classes_)

print("샘플 수:", len(df), "라벨:", list(le.classes_))
# Out:
# 샘플 수: 1086465 라벨: ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']

# %%
# ===============================
# 1. 윈도우 생성 함수 (Time-windowing)
# ===============================
import numpy as np

def create_windows(df, window_size=128, step=64):
    """
    user 단위로 데이터를 잘라서
    window_size 길이의 구간을 step 간격으로 슬라이딩하면서
    [x, y, z] 시계열과 그 윈도우의 대표 라벨(label_id, 다수결)을 만든다.
    """
    X_list = []
    y_list = []

    for user, user_df in df.groupby("user"):
        # 시간 순서대로 정렬 (안전하게)
        user_df = user_df.reset_index(drop=True)

        data = user_df[["x", "y", "z"]].values   # (len_user, 3)
        labels = user_df["label_id"].values      # (len_user,)

        for start in range(0, len(user_df) - window_size + 1, step):
            end = start + window_size
            window_data = data[start:end]        # (window_size, 3)
            window_labels = labels[start:end]    # (window_size,)

            # 윈도우 안 라벨의 다수결
            majority_label = np.bincount(window_labels).argmax()

            X_list.append(window_data)
            y_list.append(majority_label)

    X = np.array(X_list)        # (num_windows, window_size, 3)
    y = np.array(y_list)        # (num_windows,)

    print("생성된 윈도우 개수:", X.shape[0])
    print("각 윈도우 길이:", X.shape[1])
    print("특성 수:", X.shape[2])
    return X, y

WINDOW_SIZE = 128
STEP = 64
X, y = create_windows(df, window_size=WINDOW_SIZE, step=STEP)
num_features = X.shape[2]
# Out:
# 생성된 윈도우 개수: 16922
# 각 윈도우 길이: 128
# 특성 수: 3

# %%
# ===============================
# 2. 표준화 (StandardScaler 사용)
# ===============================
from sklearn.preprocessing import StandardScaler

X_2d = X.reshape(-1, num_features)  # (num_windows*window_size, num_features)

scaler = StandardScaler()
X_2d_scaled = scaler.fit_transform(X_2d)
X_2d_scaled = np.clip(X_2d_scaled, -10, 10)
X_scaled = X_2d_scaled.reshape(X.shape[0], X.shape[1], num_features)

print("스케일링 후 X_scaled shape:", X_scaled.shape)
# Out:
# 스케일링 후 X_scaled shape: (16922, 128, 3)

# %%
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=RANDOM_SEED,stratify=y)

print("Train shape:", X_train.shape, "Test shape:", X_test.shape)
print("Train 라벨 분포:", np.bincount(y_train))
print("Test 라벨 분포:", np.bincount(y_test))
# Out:
# Train shape: (13537, 128, 3) Test shape: (3385, 128, 3)
# Train 라벨 분포: [1250 4200  745  591 1535 5216]
# Test 라벨 분포: [ 313 1050  186  148  384 1304]

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Flatten, Dense

input_shape = (WINDOW_SIZE, num_features)

model = Sequential([
    # LSTM 블록
    LSTM(128, return_sequences=True, input_shape=input_shape),
    Dropout(0.2),

    LSTM(128, return_sequences=False),
    Dropout(0.3),

    # 완전연결층
    Dense(128, activation='relu'),
    Dropout(0.3),

    Dense(num_classes, activation='softmax')  # ← 분류 모델 기준
])

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 128, 128)       │        67,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 216,454 (845.52 KB)
#  Trainable params: 216,454 (845.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
EPOCHS = 20
BATCH_SIZE = 128

history = model.fit(
    X_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.2,

    verbose=1
)
# Out:
# Epoch 1/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.5571 - loss: 1.3036 - val_accuracy: 0.7290 - val_loss: 0.8383
# Epoch 2/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7305 - loss: 0.8472 - val_accuracy: 0.7574 - val_loss: 0.7194
# Epoch 3/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7593 - loss: 0.7291 - val_accuracy: 0.7722 - val_loss: 0.7724
# Epoch 4/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7709 - loss: 0.6879 - val_accuracy: 0.7677 - val_loss: 0.6313
# Epoch 5/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7804 - loss: 0.6130 - val_accuracy: 0.7755 - val_loss: 0.6434
# Epoch 6/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8000 - loss: 0.5647 - val_accuracy: 0.8209 - val_loss: 0.5250
# Epoch 7/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8125 - loss: 0.5259 - val_accuracy: 0.8194 - val_loss: 0.4961
# Epoch 8/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8177 - loss: 0.5027 - val_accuracy: 0.8275 - val_loss: 0.4911
# Epoch 9/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8414 - loss: 0.4362 - val_accuracy: 0.8456 - val_loss: 0.4181
# Epoch 10/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8480 - loss: 0.4071 - val_accuracy: 0.8530 - val_loss: 0.4052
# Epoch 11/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8663 - loss: 0.3918 - val_accuracy: 0.8490 - val_loss: 0.5602
# Epoch 12/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8505 - loss: 0.4437 - val_accuracy: 0.7943 - val_loss: 0.4798
# Epoch 13/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8219 - loss: 0.4900 - val_accuracy: 0.8907 - val_loss: 0.3173
# Epoch 14/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8959 - loss: 0.3264 - val_accuracy: 0.9121 - val_loss: 0.2487
# Epoch 15/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9069 - loss: 0.2832 - val_accuracy: 0.9073 - val_loss: 0.2556
# Epoch 16/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9031 - loss: 0.2970 - val_accuracy: 0.8874 - val_loss: 0.3168
# Epoch 17/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8931 - loss: 0.3219 - val_accuracy: 0.9103 - val_loss: 0.2627
# Epoch 18/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9230 - loss: 0.2444 - val_accuracy: 0.9306 - val_loss: 0.2428
# Epoch 19/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9341 - loss: 0.2148 - val_accuracy: 0.9376 - val_loss: 0.1995
# Epoch 20/20
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9362 - loss: 0.2042 - val_accuracy: 0.9487 - val_loss: 0.1652

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title("Training vs Validation Accuracy")
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

y_pred_proba = model.predict(X_test)
y_pred = np.argmax(y_pred_proba, axis=1)

print("\n분류 리포트:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

print("\n혼동 행렬:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Test Loss: 0.1828, Test Accuracy: 0.9456
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# 분류 리포트:
#               precision    recall  f1-score   support
#
#   Downstairs       0.84      0.86      0.85       313
#      Jogging       0.98      0.98      0.98      1050
#      Sitting       0.99      0.92      0.96       186
#     Standing       0.91      0.98      0.94       148
#     Upstairs       0.86      0.85      0.86       384
#      Walking       0.97      0.97      0.97      1304
#
#     accuracy                           0.95      3385
#    macro avg       0.92      0.93      0.93      3385
# weighted avg       0.95      0.95      0.95      3385
#
#
# 혼동 행렬:
# [[ 269    4    0    2   32    6]
#  [   0 1024    1    1   10   14]
#  [   1    0  172   10    3    0]
#  [   0    0    0  145    3    0]
#  [  22   11    0    1  328   22]
#  [  30    6    0    1    4 1263]]
